# %%
from kafka import KafkaConsumer, KafkaProducer
from time import sleep
from json import dumps,loads
import json
import s3fs
from s3fs import S3FileSystem

# %%
consumer = KafkaConsumer('demotest',bootstrap_servers=['18.116.26.230:9092'], value_deserializer=lambda x:loads(x.decode('utf-8')))
# for c in consumer:
#     print(c.value)

# %%
# import boto3

# s3 = boto3.client('s3', region_name='us-east-2')

# %%
s3 = S3FileSystem()
s3 = s3fs.S3FileSystem(client_kwargs={'region_name': 'us-east-2'})

# %%
for count, i in enumerate(consumer):
   with s3.open(f"s3://kafka-smp-bucket/stock_market_{count}.json", 'w') as f:
       json.dump(i.value, f)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/aiohttp/connector.py:1351, in TCPConnector._create_direct_connection(self, req, traces, timeout, client_error)
#    1347 try:
#    1348     # Cancelling this lookup should not cancel the underlying lookup
#    1349     #  or else the cancel event will get broadcast to all the waiters
#    1350     #  across all connections.
# -> 1351     hosts = await self._resolve_host(host, port, traces=traces)
#    1352 except OSError as exc:
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/aiohttp/connector.py:995, in TCPConnector._resolve_host(self, host, port, traces)
#     994 try:
# --> 995     return await asyncio.shield(resolved_host_task)
#     996 except asyncio.CancelledError:
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/aiohttp/connector.py:1026, in TCPConnector._resolve_host_with_throttle(self, key, host, port, futures, traces)
#    1024         await trace.send_dns_resolvehost_start(host)
# -> 1026 addrs = await self._resolver.resolve(host, port, family=self._family)
#    1027 if traces:
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/aiohttp/resolver.py:39, in ThreadedResolver.resolve(self, host, port, family)
#      36 async def resolve(
#      37     self, host: str, port: int = 0, family: socket.AddressFamily = socket.AF_INET
#      38 ) -> List[ResolveResult]:
# ---> 39     infos = await self._loop.getaddrinfo(
#      40         host,
#      41         port,
#      42         type=socket.SOCK_STREAM,
#      43         family=family,
#      44         flags=_AI_ADDRCONFIG,
#      45     )
#      47     hosts: List[ResolveResult] = []
#
# File /opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/asyncio/base_events.py:939, in BaseEventLoop.getaddrinfo(self, host, port, family, type, proto, flags)
#     937     getaddr_func = socket.getaddrinfo
# --> 939 return await self.run_in_executor(
#     940     None, getaddr_func, host, port, family, type, proto, flags)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/concurrent/futures/thread.py:59, in _WorkItem.run(self)
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/socket.py:977, in getaddrinfo(host, port, family, type, proto, flags)
#     976 addrlist = []
# --> 977 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     978     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# The above exception was the direct cause of the following exception:
#
# ClientConnectorDNSError                   Traceback (most recent call last)
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/aiobotocore/httpsession.py:222, in AIOHTTPSession.send(self, request)
#     221 session = await self._get_session(proxy_url)
# --> 222 response = await session.request(
#     223     request.method,
#     224     url=url,
#     225     chunked=self._chunked(headers_),
#     226     headers=headers_,
#     227     data=data,
#     228     proxy=proxy_url,
#     229     proxy_headers=proxy_headers,
#     230 )
#     232 # botocore converts keys to str, so make sure that they are in
#     233 # the expected case. See detailed discussion here:
#     234 # https://github.com/aio-libs/aiobotocore/pull/116
#     235 # aiohttp's CIMultiDict camel cases the headers :(
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/aiohttp/client.py:703, in ClientSession._request(self, method, str_or_url, params, data, json, cookies, headers, skip_auto_headers, auth, allow_redirects, max_redirects, compress, chunked, expect100, raise_for_status, read_until_eof, proxy, proxy_auth, timeout, verify_ssl, fingerprint, ssl_context, ssl, server_hostname, proxy_headers, trace_request_ctx, read_bufsize, auto_decompress, max_line_size, max_field_size)
#     702 try:
# --> 703     conn = await self._connector.connect(
#     704         req, traces=traces, timeout=real_timeout
#     705     )
#     706 except asyncio.TimeoutError as exc:
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/aiohttp/connector.py:548, in BaseConnector.connect(self, req, traces, timeout)
#     547         await trace.send_connection_create_start()
# --> 548 proto = await self._create_connection(req, traces, timeout)
#     549 if traces:
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/aiohttp/connector.py:1056, in TCPConnector._create_connection(self, req, traces, timeout)
#    1055 else:
# -> 1056     _, proto = await self._create_direct_connection(req, traces, timeout)
#    1058 return proto
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/aiohttp/connector.py:1357, in TCPConnector._create_direct_connection(self, req, traces, timeout, client_error)
#    1355     # in case of proxy it is not ClientProxyConnectionError
#    1356     # it is problem of resolving proxy ip itself
# -> 1357     raise ClientConnectorDNSError(req.connection_key, exc) from exc
#    1359 last_exc: Optional[Exception] = None
#
# ClientConnectorDNSError: Cannot connect to host kafka-smp-bucket.s3.Ohious-east-2.amazonaws.com:443 ssl:default [nodename nor servname provided, or not known]
#
# During handling of the above exception, another exception occurred:
#
# EndpointConnectionError                   Traceback (most recent call last)
# Cell In[38], line 2
#       1 for count, i in enumerate(consumer):
# ----> 2    with s3.open(f"s3://kafka-smp-bucket/stock_market_{count}.json", 'w') as f:
#       3        json.dump(i.value, f)
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/fsspec/spec.py:2178, in AbstractBufferedFile.close(self)
#    2176 else:
#    2177     if not self.forced:
# -> 2178         self.flush(force=True)
#    2180     if self.fs is not None:
#    2181         self.fs.invalidate_cache(self.path)
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/fsspec/spec.py:2041, in AbstractBufferedFile.flush(self, force)
#    2038         self.closed = True
#    2039         raise
# -> 2041 if self._upload_chunk(final=force) is not False:
#    2042     self.offset += self.buffer.seek(0, 2)
#    2043     self.buffer = io.BytesIO()
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/s3fs/core.py:2451, in S3File._upload_chunk(self, final)
#    2448             upload_part(self.buffer.read(self.part_max))
#    2450 if self.autocommit and final:
# -> 2451     self.commit()
#    2452 else:
#    2453     # update 'upload offset'
#    2454     self.offset += self.buffer.tell()
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/s3fs/core.py:2476, in S3File.commit(self)
#    2474     if self.acl:
#    2475         kw["ACL"] = self.acl
# -> 2476     write_result = self._call_s3("put_object", **kw)
#    2477 else:
#    2478     raise RuntimeError
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/s3fs/core.py:2311, in S3File._call_s3(self, method, *kwarglist, **kwargs)
#    2310 def _call_s3(self, method, *kwarglist, **kwargs):
# -> 2311     return self.fs.call_s3(method, self.s3_additional_kwargs, *kwarglist, **kwargs)
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/fsspec/asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     115 @functools.wraps(func)
#     116 def wrapper(*args, **kwargs):
#     117     self = obj or args[0]
# --> 118     return sync(self.loop, func, *args, **kwargs)
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/fsspec/asyn.py:103, in sync(loop, func, timeout, *args, **kwargs)
#     101     raise FSTimeoutError from return_result
#     102 elif isinstance(return_result, BaseException):
# --> 103     raise return_result
#     104 else:
#     105     return return_result
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/fsspec/asyn.py:56, in _runner(event, coro, result, timeout)
#      54     coro = asyncio.wait_for(coro, timeout=timeout)
#      55 try:
# ---> 56     result[0] = await coro
#      57 except Exception as ex:
#      58     result[0] = ex
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/s3fs/core.py:371, in S3FileSystem._call_s3(self, method, *akwarglist, **kwargs)
#     369 logger.debug("CALL: %s - %s - %s", method.__name__, akwarglist, kw2)
#     370 additional_kwargs = self._get_s3_method_kwargs(method, *akwarglist, **kwargs)
# --> 371 return await _error_wrapper(
#     372     method, kwargs=additional_kwargs, retries=self.retries
#     373 )
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/s3fs/core.py:146, in _error_wrapper(func, args, kwargs, retries)
#     144         err = e
#     145 err = translate_boto_error(err)
# --> 146 raise err
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/s3fs/core.py:114, in _error_wrapper(func, args, kwargs, retries)
#     112 for i in range(retries):
#     113     try:
# --> 114         return await func(*args, **kwargs)
#     115     except S3_RETRYABLE_ERRORS as e:
#     116         err = e
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/aiobotocore/client.py:394, in AioBaseClient._make_api_call(self, operation_name, api_params)
#     390     maybe_compress_request(
#     391         self.meta.config, request_dict, operation_model
#     392     )
#     393     apply_request_checksum(request_dict)
# --> 394     http, parsed_response = await self._make_request(
#     395         operation_model, request_dict, request_context
#     396     )
#     398 await self.meta.events.emit(
#     399     f'after-call.{service_id}.{operation_name}',
#     400     http_response=http,
#    (...)    403     context=request_context,
#     404 )
#     406 if http.status_code >= 300:
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/aiobotocore/client.py:420, in AioBaseClient._make_request(self, operation_model, request_dict, request_context)
#     416 async def _make_request(
#     417     self, operation_model, request_dict, request_context
#     418 ):
#     419     try:
# --> 420         return await self._endpoint.make_request(
#     421             operation_model, request_dict
#     422         )
#     423     except Exception as e:
#     424         await self.meta.events.emit(
#     425             f'after-call-error.{self._service_model.service_id.hyphenize()}.{operation_model.name}',
#     426             exception=e,
#     427             context=request_context,
#     428         )
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/aiobotocore/endpoint.py:90, in AioEndpoint._send_request(self, request_dict, operation_model)
#      86 request = await self.create_request(request_dict, operation_model)
#      87 success_response, exception = await self._get_response(
#      88     request, operation_model, context
#      89 )
# ---> 90 while await self._needs_retry(
#      91     attempts,
#      92     operation_model,
#      93     request_dict,
#      94     success_response,
#      95     exception,
#      96 ):
#      97     attempts += 1
#      98     self._update_retries_context(context, attempts, success_response)
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/aiobotocore/endpoint.py:261, in AioEndpoint._needs_retry(self, attempts, operation_model, request_dict, response, caught_exception)
#     259 service_id = operation_model.service_model.service_id.hyphenize()
#     260 event_name = f"needs-retry.{service_id}.{operation_model.name}"
# --> 261 responses = await self._event_emitter.emit(
#     262     event_name,
#     263     response=response,
#     264     endpoint=self,
#     265     operation=operation_model,
#     266     attempts=attempts,
#     267     caught_exception=caught_exception,
#     268     request_dict=request_dict,
#     269 )
#     270 handler_response = first_non_none_response(responses)
#     271 if handler_response is None:
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/aiobotocore/hooks.py:68, in AioHierarchicalEmitter._emit(self, event_name, kwargs, stop_on_response)
#      65 logger.debug('Event %s: calling handler %s', event_name, handler)
#      67 # Await the handler if its a coroutine.
# ---> 68 response = await resolve_awaitable(handler(**kwargs))
#      69 responses.append((handler, response))
#      70 if stop_on_response and response is not None:
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/aiobotocore/_helpers.py:6, in resolve_awaitable(obj)
#       4 async def resolve_awaitable(obj):
#       5     if inspect.isawaitable(obj):
# ----> 6         return await obj
#       8     return obj
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/aiobotocore/retryhandler.py:107, in AioRetryHandler._call(self, attempts, response, caught_exception, **kwargs)
#     104     retries_context = kwargs['request_dict']['context'].get('retries')
#     105     checker_kwargs.update({'retries_context': retries_context})
# --> 107 if await resolve_awaitable(self._checker(**checker_kwargs)):
#     108     result = self._action(attempts=attempts)
#     109     logger.debug("Retry needed, action of: %s", result)
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/aiobotocore/_helpers.py:6, in resolve_awaitable(obj)
#       4 async def resolve_awaitable(obj):
#       5     if inspect.isawaitable(obj):
# ----> 6         return await obj
#       8     return obj
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/aiobotocore/retryhandler.py:126, in AioMaxAttemptsDecorator._call(self, attempt_number, response, caught_exception, retries_context)
#     121 if retries_context:
#     122     retries_context['max'] = max(
#     123         retries_context.get('max', 0), self._max_attempts
#     124     )
# --> 126 should_retry = await self._should_retry(
#     127     attempt_number, response, caught_exception
#     128 )
#     129 if should_retry:
#     130     if attempt_number >= self._max_attempts:
#     131         # explicitly set MaxAttemptsReached
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/aiobotocore/retryhandler.py:165, in AioMaxAttemptsDecorator._should_retry(self, attempt_number, response, caught_exception)
#     161         return True
#     162 else:
#     163     # If we've exceeded the max attempts we just let the exception
#     164     # propagate if one has occurred.
# --> 165     return await resolve_awaitable(
#     166         self._checker(attempt_number, response, caught_exception)
#     167     )
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/aiobotocore/_helpers.py:6, in resolve_awaitable(obj)
#       4 async def resolve_awaitable(obj):
#       5     if inspect.isawaitable(obj):
# ----> 6         return await obj
#       8     return obj
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/aiobotocore/retryhandler.py:174, in AioMultiChecker._call(self, attempt_number, response, caught_exception)
#     171 async def _call(self, attempt_number, response, caught_exception):
#     172     for checker in self._checkers:
#     173         checker_response = await resolve_awaitable(
# --> 174             checker(attempt_number, response, caught_exception)
#     175         )
#     176         if checker_response:
#     177             return checker_response
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/botocore/retryhandler.py:247, in BaseChecker.__call__(self, attempt_number, response, caught_exception)
#     245     return self._check_response(attempt_number, response)
#     246 elif caught_exception is not None:
# --> 247     return self._check_caught_exception(
#     248         attempt_number, caught_exception
#     249     )
#     250 else:
#     251     raise ValueError("Both response and caught_exception are None.")
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/botocore/retryhandler.py:416, in ExceptionRaiser._check_caught_exception(self, attempt_number, caught_exception)
#     408 def _check_caught_exception(self, attempt_number, caught_exception):
#     409     # This is implementation specific, but this class is useful by
#     410     # coordinating with the MaxAttemptsDecorator.
#    (...)    414     # the MaxAttemptsDecorator is not interested in retrying the exception
#     415     # then this exception just propagates out past the retry code.
# --> 416     raise caught_exception
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/aiobotocore/endpoint.py:171, in AioEndpoint._do_get_response(self, request, operation_model, context)
#     169     http_response = first_non_none_response(responses)
#     170     if http_response is None:
# --> 171         http_response = await self._send(request)
#     172 except HTTPClientError as e:
#     173     return (None, e)
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/aiobotocore/endpoint.py:284, in AioEndpoint._send(self, request)
#     283 async def _send(self, request):
# --> 284     return await self.http_session.send(request)
#
# File ~/Downloads/Kafka_Stock_Market_Analysis/Kafka_Stock_Market_Analysis/path/to/venv/lib/python3.13/site-packages/aiobotocore/httpsession.py:276, in AIOHTTPSession.send(self, request)
#     270         raise ReadTimeoutError(endpoint_url=request.url, error=e)
#     271 except (
#     272     ClientConnectorError,
#     273     ClientConnectionError,
#     274     socket.gaierror,
#     275 ) as e:
# --> 276     raise EndpointConnectionError(endpoint_url=request.url, error=e)
#     277 except asyncio.TimeoutError as e:
#     278     raise ReadTimeoutError(endpoint_url=request.url, error=e)
#
# EndpointConnectionError: Could not connect to the endpoint URL: "https://kafka-smp-bucket.s3.Ohious-east-2.amazonaws.com/stock_market_0.json"
